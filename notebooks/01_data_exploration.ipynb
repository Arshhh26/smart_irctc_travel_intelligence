# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../data/processed/clean_train_schedule.csv")

# %%
print("Shape :", df.shape)

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
top_stations = (
    df["Station_Name"]
    .value_counts()
    .head(20)
)

# %%
plt.figure(figsize=(12,6))

top_stations.plot(kind="bar")

plt.title("Top 20 Busiest Railway Stations")
plt.xlabel("Station")
plt.ylabel("Number of Train Stops")

plt.xticks(rotation=90)

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.hist(df["Distance"], bins=40)

plt.title("Distribution of Distance Covered")

plt.xlabel("Distance (km)")
plt.ylabel("Frequency")

plt.show()

# %%
top_trains = (
    merged_df.groupby(["Train_No", "Train name"])["Distance"]
    .max()
    .sort_values(ascending=False)
    .head(15)
)

# %%
plt.figure(figsize=(14,7))

labels = [
    f"{train_no}\n{name}"
    for train_no, name in top_trains.index
]

plt.bar(labels, top_trains.values)

plt.title("Top 15 Longest Trains", fontsize=16)
plt.xlabel("Train Number & Train Name")
plt.ylabel("Maximum Distance (km)")

plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()
